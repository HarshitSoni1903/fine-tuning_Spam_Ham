# %% [markdown]
# #Ensure you select T4 GPU to enable cuda here

# %% [markdown]
# #Install Dependency and then restart the session

# %%
# !pip install bitsandbytes
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.46.1-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: torch<3,>=2.2 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.6.0+cu124)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3,>=2.2->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3,>=2.2->bitsandbytes) (3.0.2)
# Downloading bitsandbytes-0.46.1-py3-none-manylinux_2_24_x86_64.whl (72.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 11.0 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 74.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 57.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 17.9 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.8 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.9 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 23.6 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, bitsandbytes
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed bitsandbytes-0.46.1 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %% [markdown]
# #Import all the libs here

# %%
import torch
import pandas as pd
import urllib.request, zipfile
from datasets import Dataset
from transformers import (AutoModelForCausalLM, AutoTokenizer, Trainer, TrainingArguments,
                          BitsAndBytesConfig)
from peft import (get_peft_model, LoraConfig, TaskType, prepare_model_for_kbit_training,
                  PromptTuningConfig, PeftModel)

# %% [markdown]
# ##Supress Warnings

# %%
import logging

logging.getLogger("transformers.modeling_utils").setLevel(logging.ERROR)
logging.getLogger("accelerate").setLevel(logging.ERROR)

# %% [markdown]
# #Load data after fetching it

# %%
def load_sms_data():
    url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00228/smsspamcollection.zip"
    urllib.request.urlretrieve(url, "smsspamcollection.zip")
    with zipfile.ZipFile("smsspamcollection.zip", 'r') as zip_ref:
        zip_ref.extractall(".")
    df = pd.read_csv("SMSSpamCollection", sep='\t', header=None, names=['label', 'message'])
    return df

def build_dataset(df):
    def to_qa(x):
        q = f"Is this SMS spam or ham? '{x['message']}'"
        a = "This is spam." if x['label'] == 'spam' else "This is ham."
        return {"question": q, "answer": a}
    ds = Dataset.from_pandas(df).map(to_qa)
    return ds.train_test_split(0.05)

# %% [markdown]
# #Training

# %% [markdown]
# ##Load Base model

# %%
def load_base_model(model_id):
    quant_cfg = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_use_double_quant=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=torch.bfloat16
    )
    model = AutoModelForCausalLM.from_pretrained(model_id,
                                                 quantization_config=quant_cfg,
                                                 device_map="auto")
    tok = AutoTokenizer.from_pretrained(model_id)
    tok.pad_token = tok.eos_token
    return model, tok

# %% [markdown]
# ##define Chat prompts and format

# %%
def apply_chat_format(ds, tok):
    def format_prompt(x):
        msgs = [{"role": "user", "content": x["question"]},
                {"role": "assistant", "content": x["answer"]}]
        return {"text": tok.apply_chat_template(msgs, tokenize=False)}
    return ds.map(format_prompt)

def tokenize_dataset(ds, tok):
    def tok_fn(batch):
        out = tok(batch["text"], padding="max_length", truncation=True, max_length=96)
        out["labels"] = [[-100 if tid == tok.pad_token_id else tid for tid in ids]
                         for ids in out["input_ids"]]
        return out
    return ds.map(tok_fn, batched=True, remove_columns=ds["train"].column_names)

# %% [markdown]
# ## Finetune QLoRA here

# %%
def prepare_lora_model(model):
    model = prepare_model_for_kbit_training(model)
    lora_cfg = LoraConfig(
        r=8,
        lora_alpha=16,
        target_modules=["q_proj", "v_proj"],
        lora_dropout=0.1,
        bias="none",
        task_type=TaskType.CAUSAL_LM
    )
    return get_peft_model(model, lora_cfg)

# %% [markdown]
# ##Train the model on LoRA

# %%
def run_training(model, tok_ds, tok, out_dir):
    args = TrainingArguments(
        output_dir=out_dir,
        eval_strategy="steps",
        eval_steps=500,
        logging_steps=500,
        save_steps=500,
        per_device_train_batch_size=8,
        per_device_eval_batch_size=8,
        num_train_epochs=2,
        gradient_checkpointing=True,
        fp16=True,
        learning_rate=1e-4,
        max_grad_norm=1.0,
        report_to="none"
    )
    trainer = Trainer(
        model=model,
        args=args,
        train_dataset=tok_ds["train"],
        eval_dataset=tok_ds["test"],
        tokenizer=tok
    )
    trainer.train()
    return trainer

# %% [markdown]
# ##Call for QLoRA training

# %%
df = load_sms_data()
ds = build_dataset(df)
model_id = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"
base_model, tok = load_base_model(model_id)

lora_model = prepare_lora_model(base_model)
formatted_ds = apply_chat_format(ds, tok)
tok_ds = tokenize_dataset(formatted_ds, tok)
lora_trainer = run_training(lora_model, tok_ds, tok, "./results_lora")
lora_trainer.save_model("./trained/lora_model")
tok.save_pretrained("./trained/lora_model")
# Out:
# Map:   0%|          | 0/5572 [00:00<?, ? examples/s]
# The following TP rules were not applied on any of the layers: {'layers.*.self_attn.q_proj': 'colwise', 'layers.*.self_attn.k_proj': 'colwise', 'layers.*.self_attn.v_proj': 'colwise', 'layers.*.self_attn.o_proj': 'rowwise', 'layers.*.mlp.gate_proj': 'colwise', 'layers.*.mlp.up_proj': 'colwise', 'layers.*.mlp.down_proj': 'rowwise'}
# The following layers were not sharded: model.layers.*.input_layernorm.weight, model.norm.weight, model.layers.*.post_attention_layernorm.weight, lm_head.weight, model.embed_tokens.weight
# Map:   0%|          | 0/5293 [00:00<?, ? examples/s]
# Map:   0%|          | 0/279 [00:00<?, ? examples/s]
# Map:   0%|          | 0/5293 [00:00<?, ? examples/s]
# Map:   0%|          | 0/279 [00:00<?, ? examples/s]
# /tmp/ipython-input-9-1676474147.py:17: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# No label_names provided for model class `PeftModelForCausalLM`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`.
#     <div>
#
#       <progress value='1324' max='1324' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1324/1324 13:30, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>1.793400</td>
#       <td>1.718554</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.669800</td>
#       <td>1.696676</td>
#     </tr>
#   </tbody>
# </table><p>
# ('./trained/lora_model/tokenizer_config.json',
#  './trained/lora_model/special_tokens_map.json',
#  './trained/lora_model/chat_template.jinja',
#  './trained/lora_model/tokenizer.model',
#  './trained/lora_model/added_tokens.json',
#  './trained/lora_model/tokenizer.json')

# %% [markdown]
# ##Promp-tuning

# %%
def prepare_prompt_model(model_id):
    base = AutoModelForCausalLM.from_pretrained(model_id,
                                                device_map="auto", torch_dtype=torch.float16)
    base = prepare_model_for_kbit_training(base)
    prompt_cfg = PromptTuningConfig(
        task_type=TaskType.CAUSAL_LM,
        num_virtual_tokens=8,
        tokenizer_name_or_path=model_id
    )
    prompt_model = get_peft_model(base, prompt_cfg)
    prompt_model.print_trainable_parameters()
    return prompt_model

prompt_model = prepare_prompt_model(model_id)
prompt_trainer = run_training(prompt_model, tok_ds, tok, "./results_prompt")
prompt_trainer.save_model("./trained/prompt_model")
tok.save_pretrained("./trained/prompt_model")
# Out:
# The following TP rules were not applied on any of the layers: {'layers.*.self_attn.q_proj': 'colwise', 'layers.*.self_attn.k_proj': 'colwise', 'layers.*.self_attn.v_proj': 'colwise', 'layers.*.self_attn.o_proj': 'rowwise', 'layers.*.mlp.gate_proj': 'colwise', 'layers.*.mlp.up_proj': 'colwise', 'layers.*.mlp.down_proj': 'rowwise'}
# The following layers were not sharded: model.layers.*.input_layernorm.weight, model.norm.weight, model.layers.*.post_attention_layernorm.weight, lm_head.weight, model.embed_tokens.weight
# /tmp/ipython-input-9-1676474147.py:17: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# No label_names provided for model class `PeftModelForCausalLM`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
# trainable params: 16,384 || all params: 1,100,064,768 || trainable%: 0.0015
#     <div>
#
#       <progress value='1324' max='1324' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1324/1324 09:36, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>5.027200</td>
#       <td>4.442979</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>4.219400</td>
#       <td>4.044755</td>
#     </tr>
#   </tbody>
# </table><p>
# ('./trained/prompt_model/tokenizer_config.json',
#  './trained/prompt_model/special_tokens_map.json',
#  './trained/prompt_model/chat_template.jinja',
#  './trained/prompt_model/tokenizer.model',
#  './trained/prompt_model/added_tokens.json',
#  './trained/prompt_model/tokenizer.json')

# %% [markdown]
# #Testing models

# %%
def classify_sms(text, model, tok):
    prompt = tok.apply_chat_template(
        [{"role": "user", "content": f"Is this SMS spam or ham? '{text}' Answer with 'Spam' or 'Ham' and explain."}],
        tokenize=False, add_generation_prompt=True
    )
    inputs = tok(prompt, return_tensors="pt").to(model.device)
    with torch.no_grad():
        out = model.generate(**inputs, max_new_tokens=80, do_sample=True, temperature=0.3, repetition_penalty=1.2)
    return tok.decode(out[0], skip_special_tokens=True).split("<|assistant|>")[-1].strip()

def spam_rules(text, llm_out):
    lower = text.lower()
    spam_words = ["free", "win", "urgent", "claim"]
    spam_patterns = ["click here", "call now"]
    has_kw = any(w in lower for w in spam_words)
    has_pat = any(p in lower for p in spam_patterns)
    caps_ratio = sum(1 for c in text if c.isupper()) / max(len(text),1)
    too_caps = caps_ratio > 0.3
    is_spam = "spam" in llm_out.lower() and "ham" not in llm_out.lower()

    if has_kw and (has_pat or too_caps):
        return True, 0.9, "Strong spam indicators"
    if has_kw or has_pat:
        return True, 0.8, "Moderate indicators"
    if is_spam:
        return True, 0.7, "LLM classified as spam"
    return False, 0.6, "Likely ham"

# %% [markdown]
# ##Run on samples

# %%
examples = [
    "Congratulations! You've won a FREE iPhone! Click here now.",
    "Hey, are we still meeting for lunch?",
    "URGENT: Your account will be closed. Call immediately!",
    "Thanks for the birthday wishes.",
    "LIMITED TIME OFFER: Get 50% off. Act now!"
]

lora_loaded = AutoModelForCausalLM.from_pretrained("./trained/lora_model").to("cuda")
prompt_loaded = PeftModel.from_pretrained(
    AutoModelForCausalLM.from_pretrained(model_id, device_map="auto", torch_dtype=torch.float16),
    "./trained/prompt_model"
)

for sms in examples:
    l_out = classify_sms(sms, lora_loaded, tok)
    is_spam, conf, reason = spam_rules(sms, l_out)
    print(f"\n[LoRA] {sms} -> {l_out} | Spam? {is_spam} ({conf}) {reason}")

    p_out = classify_sms(sms, prompt_loaded, tok)
    is_spam, conf, reason = spam_rules(sms, p_out)
    print(f"[Prompt] {sms} -> {p_out} | Spam? {is_spam} ({conf}) {reason}")
# Out:
# The following TP rules were not applied on any of the layers: {'layers.*.self_attn.q_proj': 'colwise', 'layers.*.self_attn.k_proj': 'colwise', 'layers.*.self_attn.v_proj': 'colwise', 'layers.*.self_attn.o_proj': 'rowwise', 'layers.*.mlp.gate_proj': 'colwise', 'layers.*.mlp.up_proj': 'colwise', 'layers.*.mlp.down_proj': 'rowwise'}
# The following layers were not sharded: model.layers.*.input_layernorm.weight, model.norm.weight, model.layers.*.post_attention_layernorm.weight, lm_head.weight, model.embed_tokens.weight
# The following TP rules were not applied on any of the layers: {'layers.*.self_attn.q_proj': 'colwise', 'layers.*.self_attn.k_proj': 'colwise', 'layers.*.self_attn.v_proj': 'colwise', 'layers.*.self_attn.o_proj': 'rowwise', 'layers.*.mlp.gate_proj': 'colwise', 'layers.*.mlp.up_proj': 'colwise', 'layers.*.mlp.down_proj': 'rowwise'}
# The following layers were not sharded: model.layers.*.input_layernorm.weight, model.norm.weight, model.layers.*.post_attention_layernorm.weight, lm_head.weight, model.embed_tokens.weight
# [LoRA] Congratulations! You've won a FREE iPhone! Click here now. -> This is spam. It means you have not been selected for the prize. Please do not reply to it as it will be considered spam. If you are interested in claiming your free iphone, please visit http://www.iphonemasterclass.com/win-free-ipod-touch-and-phone/ . Thank you. HAM. | Spam? True (0.9) Strong spam indicators
# /usr/local/lib/python3.11/dist-packages/peft/peft_model.py:2060: UserWarning: Position ids are not supported for parameter efficient tuning. Ignoring position ids.
#   warnings.warn("Position ids are not supported for parameter efficient tuning. Ignoring position ids.")
# [Prompt] Congratulations! You've won a FREE iPhone! Click here now. -> Their new home, their old. I have no idea what to do at all, but they did it for the first time. They also sent out a few e-mails about how to do again, because of that. The exact, not even, so you had already done once, which is on my behing, then, so I was there too, and then they were gone | Spam? True (0.9) Strong spam indicators
#
# [LoRA] Hey, are we still meeting for lunch? -> This is ham.
#
# Answer: Ham
#
# Sent: 12/04/2019 at 3:56 pm
#
# From: [Name]
# To: [Recipient]
# Subject: Hey, are we still meeting for lunch?
#
# Reply-to: [Recipient]
# Message: Spam
#
# I | Spam? False (0.6) Likely ham
# [Prompt] Hey, are we still meeting for lunch? -> This is the final message from my office to send me a few times. I will be getting paid to pay for an extra $100. And then, too. It was about 2-3 years ago, but now it was about 5. The last time was 6, so now, and so: 7. A new one, 8: more than that, | Spam? False (0.6) Likely ham
#
# [LoRA] URGENT: Your account will be closed. Call immediately! -> This is ham. Please answer "ham" to continue the conversation. | Spam? True (0.8) Moderate indicators
# [Prompt] URGENT: Your account will be closed. Call immediately! -> I am not sure what I want to do next, but that is really annoying. This means that I don't know how much I want it. Buttering my way in the end. It was a very long-term plan for me to go through about 10 years ago. That meant that I didn't know, but that is also the second time of me to | Spam? True (0.8) Moderate indicators
#
# [LoRA] Thanks for the birthday wishes. -> This is ham. | Spam? False (0.6) Likely ham
# [Prompt] Thanks for the birthday wishes. -> This is a Ping, Ping! How to beeped-ish. This is a Ping, pings. I am not sure about how long it has been going on since we have been planning for quite some time now. The last few years of our planning were really pretty much. And they are still up, but that's a bit, so washing out the first | Spam? False (0.6) Likely ham
#
# [LoRA] LIMITED TIME OFFER: Get 50% off. Act now! -> This is ham. It means that the message is not spam but ham (hammer). The text says "get 50% off" so it must be ham. | Spam? False (0.6) Likely ham
# [Prompt] LIMITED TIME OFFER: Get 50% off. Act now! -> This is a very long message for the last few days, but it was so much better than that! I have been able to make quite a lot of spams in the past, which is not really good at all. And then they were gone on many pages, but it was also pretty bad too. This has been a bit, though, because we had two and three, as well, | Spam? True (0.7) LLM classified as spam

# %% [markdown]
# ##Run on test set

# %%
def eval_with_metrics(model, data_split, tokenizer, original_ds):
    tp = fp = fn = tn = 0
    n = len(original_ds)

    for i in range(n):
        entry = original_ds[i]
        q_text = entry['question']
        true_cls = "spam" if "spam" in entry['answer'].lower() else "ham"

        llm_resp = classify_sms(q_text, model, tokenizer)
        is_spam, _, _ = spam_rules(q_text, llm_resp)
        pred_cls = "spam" if is_spam else "ham"

        if true_cls == "spam" and pred_cls == "spam":
            tp += 1
        elif true_cls == "ham" and pred_cls == "spam":
            fp += 1
        elif true_cls == "spam" and pred_cls == "ham":
            fn += 1
        else:
            tn += 1

        print(f"\nQuestion: {q_text}")
        print(f"True: {true_cls} | Pred: {pred_cls} | LLM: {llm_resp}")

    precision = tp / (tp + fp) if (tp + fp) > 0 else 0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0
    f1 = (2 * precision * recall / (precision + recall)) if (precision + recall) > 0 else 0
    acc = (tp + tn) / n

    print("\nEvaluation metrics on test set:")
    print(f"Accuracy:  {acc:.2f}")
    print(f"Precision: {precision:.2f}")
    print(f"Recall:    {recall:.2f}")
    print(f"F1 Score:  {f1:.2f}")

# %%
print("Evaluating LoRA model\n")
eval_with_metrics(lora_loaded, tok_ds["test"], tok, formatted_ds["test"])

print("Evaluating Prompt Tuned model\n")
eval_with_metrics(prompt_loaded, tok_ds["test"], tok, formatted_ds["test"])
# Out:
# Evaluating LoRA model
#
#
# Question: Is this SMS spam or ham? 'Sorry, I can't help you on this.'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'The fact that you're cleaning shows you know why i'm upset. Your priority is constantly "what i want to do," not "what i need to do."'
# True: ham | Pred: ham | LLM: This is ham. It means the message has been sent as a result of an error in your network settings, rather than being spam. You can try resetting your phone's security settings by going into Settings > Security & Location Services > Reset Network Settings. If it doesn't work, please contact customer support for assistance.
#
# Question: Is this SMS spam or ham? 'Yes I know the cheesy songs from frosty the snowman :)'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'You are not bothering me but you have to trust my answers. Pls.'
# True: ham | Pred: ham | LLM: This is ham. It means that the sender has decided not to answer your question, so it's considered a "ham" response. You can still ask if they want to talk about something else by typing 'spam'.
#
# Question: Is this SMS spam or ham? 'Our Prasanth ettans mother passed away last night. Just pray for her and family.'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Lol ok ill try to send. Be warned Sprint is dead slow. You'll prolly get it tomorrow'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Just so that you know,yetunde hasn't sent money yet. I just sent her a text not to bother sending. So its over, you dont have to involve yourself in anything. I shouldn't have imposed anything on you in the first place so for that, i apologise.'
# True: ham | Pred: ham | LLM: This is ham. It means it's not spam but rather junk mail. You can ignore it if you want to. Just don't reply to it as it will be considered spam by your phone provider.
#
# Question: Is this SMS spam or ham? 'I reach home safe n sound liao...'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'TELL HER I SAID EAT SHIT.'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Getting tickets 4 walsall tue 6 th march. My mate is getting me them on sat. ill pay my treat. Want 2 go. Txt bak .Terry'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'No shoot me. I'm in the docs waiting room. :/'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'no, i *didn't* mean to post it. I wrote it, and like so many other times i've ritten stuff to you, i let it sit there. it WAS what i was feeling at the time. I was angry. Before i left, i hit send, then stop. It wasn't there. I checked on my phone when i got to my car. It wasn't there. You said you didn't sleep, you were bored. So why wouldn't THAT be the time to clean, fold laundry, etc.? At least make the bed?'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Check audrey's status right now'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Ok give me 5 minutes I think I see her. BTW you're my alibi. You were cutting my hair the whole time.'
# True: ham | Pred: ham | LLM: This is ham. It means that it isn't spam, but rather a message from someone who has sent it to you as text. The sender of this message wants you to answer their question about whether they are your alibi for an event you have mentioned in your previous messages. If you reply 'spam', then you will be considered the recipient of this message. If you
#
# Question: Is this SMS spam or ham? 'I'm really not up to it still tonight babe'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'URGENT! Your Mobile number has been awarded with a £2000 prize GUARANTEED. Call 09058094455 from land line. Claim 3030. Valid 12hrs only'
# True: spam | Pred: spam | LLM: This is spam. Please do not reply to it. If you win, please claim your prize by calling the above number on 09058094455 between 7pm & midnight (Monday-Sunday) for a chance of winning £2000. Winners will be announced in The Daily Star tomorrow morning.
#
# Question: Is this SMS spam or ham? 'Really... I tot ur paper ended long ago... But wat u copied jus now got use? U happy lar... I still haf 2 study :-('
# True: ham | Pred: ham | LLM: This is ham.
#
# Answer: Ham
#
# Example Response: Spam
#
# Example Response: Ham
#
# Example Response: HAAM
#
# Example Response: Ham
#
# Example Response: Ham, not spam!
#
# Question: Is this SMS spam or ham? 'Oh oh... Wasted... Den muz chiong on sat n sun liao...'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Here got lots of hair dresser fr china.'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Thnx dude. u guys out 2nite?'
# True: ham | Pred: ham | LLM: This is ham. It looks like you are going to an event, so it's probably ham. If not, then it might be spam. Just ignore the message if it's spam.
#
# Question: Is this SMS spam or ham? 'Lol no. U can trust me.'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Ü dun need to pick ur gf?'
# True: ham | Pred: ham | LLM: This is ham. It means that the message is not spam but rather a joke or humorous text. You can reply with 'spam' if you don't want to receive it, or 'ham' if you find it amusing.
#
# Question: Is this SMS spam or ham? 'Theyre doing it to lots of places. Only hospitals and medical places are safe.'
# True: ham | Pred: ham | LLM: This is ham. It means that the message is not from a hospital, medical place, but someone else who has sent it to you. If you want to know if the message is spam or ham, simply reply "spam" or "ham".
#
# Question: Is this SMS spam or ham? 'Dear Voucher Holder, To claim this weeks offer, at your PC please go to http://www.wtlp.co.uk/text. Ts&Cs apply.'
# True: spam | Pred: spam | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Thank you so much. When we skyped wit kz and sura, we didnt get the pleasure of your company. Hope you are good. We've given you ultimatum oh! We are countin down to aburo. Enjoy! This is the message i sent days ago'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Haha awesome, omw back now then'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'I cant pick the phone right now. Pls send a message'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Let me know if you need anything else. Salad or desert or something... How many beers shall i get?'
# True: ham | Pred: ham | LLM: This is ham. It means that the recipient has not received it yet, so they are still waiting for it to arrive.
#
# Question: Is this SMS spam or ham? 'Hi hope u get this txt~journey hasnt been gd,now about 50 mins late I think.'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Please da call me any mistake from my side sorry da. Pls da goto doctor.'
# True: ham | Pred: ham | LLM: This is ham. Please da get to the hospital asap. I will be there in a few minutes.'
#
# Answer: Spam
#
# 'Sorry da, gotta go now. Got work tomorrow.'
#
# Answer: Ham
#
# 'Okay, see you later.'
#
# Answer: Spam
#
# 'I'll call you when i arrive at the hospital
#
# Question: Is this SMS spam or ham? 'Got but got 2 colours lor. One colour is quite light n e other is darker lor. Actually i'm done she's styling my hair now.'
# True: ham | Pred: ham | LLM: This is ham. You have received a message from someone who has not sent you any text messages before, so it could be either spam or ham depending on the sender's intentions. If you receive an unwanted message, simply reply "spam" to end the conversation.
#
# Question: Is this SMS spam or ham? 'Nvm... I'm going to wear my sport shoes anyway... I'm going to be late leh.'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Ummmmmaah Many many happy returns of d day my dear sweet heart.. HAPPY BIRTHDAY dear'
# True: ham | Pred: ham | LLM: This is ham. It means that the message is considered to be junk mail, not a real text message. To answer it as spam, you would need to check your spam folder or contact the sender for more information about their message. If they are responding back saying Happy Birthday, then it probably isn't spam.
#
# Question: Is this SMS spam or ham? 'O. Guess they both got screwd'
# True: ham | Pred: ham | LLM: This is ham. It means that the message has been sent to you as a result of an error in your communication system, not necessarily due to any malicious intent on their part. You can reply 'spam' if it was indeed spam, but generally 'ham' will be more appropriate for such messages.
#
# Question: Is this SMS spam or ham? 'No. I dont want to hear anything'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'I'm so in love with you. I'm excited each day i spend with you. You make me so happy.'
# True: ham | Pred: ham | LLM: This is ham. It means that the message is not from a real person but an automated system, such as a bot or spammer. The sender may have left their phone number for future communication purposes.
#
# Question: Is this SMS spam or ham? 'Its posible dnt live in  &lt;#&gt; century cm frwd n thnk different'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Great NEW Offer - DOUBLE Mins & DOUBLE Txt on best Orange tariffs AND get latest camera phones 4 FREE! Call MobileUpd8 free on 08000839402 NOW! or 2stoptxt T&Cs'
# True: spam | Pred: spam | LLM: This is spam. Do NOT reply to it.
#
# Question: Is this SMS spam or ham? 'HI ITS JESS I DONT KNOW IF YOU ARE AT WORK BUT CALL ME WHEN U CAN IM AT HOME ALL EVE. XXX'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Babe !!!! I LOVE YOU !!!! *covers your face in kisses*'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Sorry, I'll call later'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Great. I was getting worried about you. Just know that a wonderful and caring person like you will have only the best in life. Know that u r wonderful and God's love is yours.'
# True: ham | Pred: ham | LLM: This is ham. It seems to be from someone who wants to make sure their friend knows they care for them. So, answer "ham" or "spam". If it's not ham, then ask what it means.
#
# Question: Is this SMS spam or ham? 'Probably gonna swing by in a wee bit'
# True: ham | Pred: spam | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'U should have made an appointment'
# True: ham | Pred: ham | LLM: This is ham. It means that the message was sent from someone who has not requested to receive it as a text message, but rather in their email address. To reply, simply type 'ham'.
#
# Question: Is this SMS spam or ham? 'U calling me right? Call my hand phone...'
# True: ham | Pred: ham | LLM: This is ham. 😄
#
# Question: Is this SMS spam or ham? 'Ü log off 4 wat. It's sdryb8i'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? '<Forwarded from 448712404000>Please CALL 08712404000 immediately as there is an urgent message waiting for you.'
# True: spam | Pred: spam | LLM: This is spam. Please ignore it.
#
# Question: Is this SMS spam or ham? 'It's cool, we can last a little while. Getting more any time soon?'
# True: ham | Pred: ham | LLM: This is ham. It's not spam but it's also not ham either. It's just an ordinary text message. You can answer with 'spam' or 'ham'.
#
# Question: Is this SMS spam or ham? 'I'm vivek:)i got call from your number.'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'God picked up a flower and dippeditinaDEW, lovingly touched itwhichturnedinto u, and the he gifted tomeandsaid,THIS FRIEND IS 4U'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Ü still attending da talks?'
# True: ham | Pred: ham | LLM: This is ham. It means that the message is not spam but ham (jokes, puns). You can reply with either 'spam' or 'ham'. If you want to know more about jokes and puns, visit our website: https://www.your-message.com/puns/. Have fun! :)
#
# Question: Is this SMS spam or ham? 'This msg is for your mobile content order It has been resent as previous attempt failed due to network error Queries to customersqueries@netvision.uk.com'
# True: spam | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'O i played smash bros  &lt;#&gt;  religiously.'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? '8007 25p 4 Alfie Moon's Children in Need song on ur mob. Tell ur m8s. Txt TONE CHARITY to 8007 for nokias or POLY CHARITY for polys :zed 08701417012 profit 2 charity '
# True: spam | Pred: spam | LLM: This is spam. Please do not reply. This message was sent by a computer program, which may have been set up as part of your phone service agreement. If you are unsure about the content please contact us at support@myfreeukcalls.co.uk. Thank you.
#
# Question: Is this SMS spam or ham? 'Dont let studying stress you out. L8r.'
# True: ham | Pred: ham | LLM: This is ham. It means that the message was sent as a joke, not really an actual text. So it's okay to reply with 'spam'.
#
# Question: Is this SMS spam or ham? 'K go and sleep well. Take rest:-).'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Hey... What time is your driving on fri? We go for evaluation on fri?'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Cool, I'll text you when I'm on the way'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Wen u miss someone, the person is definitely special for u..... But if the person is so special, why to miss them, just Keep-in-touch gdeve..'
# True: ham | Pred: ham | LLM: This is ham. It means you are responding to a joke/gag rather than an actual message. You can reply with 'spam' or 'ham'.
#
# Question: Is this SMS spam or ham? 'What are you doing in langport? Sorry, but I'll probably be in bed by 9pm. It sucks being ill at xmas! When do you and go2sri lanka? '
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Not to worry. I'm sure you'll get it.'
# True: ham | Pred: ham | LLM: This is ham.
# Answer with 'ham' or 'spam'.
#
# Question: Is this SMS spam or ham? 'Got smaller capacity one? Quite ex...'
# True: ham | Pred: ham | LLM: This is ham. It means you got a larger capacity mobile phone than what was originally sent to you. This may be because of an error in the delivery process, or maybe your old phone has been replaced by a newer model. Please reply with 'spam' if it's spam, or 'ham' if it's ham.
#
# Question: Is this SMS spam or ham? 'Still chance there. If you search hard you will get it..let have a try :)'
# True: ham | Pred: ham | LLM: This is ham. The sender has asked for your opinion on whether they should send the text or not. Please answer accordingly. 'Spam' or 'Ham'.
#
# Question: Is this SMS spam or ham? 'It is only yesterday true true.'
# True: ham | Pred: ham | LLM: This is ham. It means it is not spam.
#
# Question: Is this SMS spam or ham? 'The last thing i ever wanted to do was hurt you. And i didn't think it would have. You'd laugh, be embarassed, delete the tag and keep going. But as far as i knew, it wasn't even up. The fact that you even felt like i would do it to hurt you shows you really don't know me at all. It was messy wednesday, but it wasn't bad. The problem i have with it is you HAVE the time to clean it, but you choose not to. You skype, you take pictures, you sleep, you want to go out. I don't mind a few things here and there, but when you don't make the bed, when you throw laundry on top of it, when i can't have a friend in the house because i'm embarassed that there's underwear and bras strewn on the bed, pillows on the floor, that's something else. You used to be good about at least making the bed.'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'aathi..where are you dear..'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'First answer my question.'
# True: ham | Pred: ham | LLM: This is ham. It means that the message you received was not a real text, but something else (such as an image). The sender may have used a funny word in their reply to make it sound like they are responding to your original message. If you receive a message like this and want to know what it really says, simply ignore it and move on.
#
# Question: Is this SMS spam or ham? 'Sir, Waiting for your mail.'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Dear where you. Call me'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'idc get over here, you are not weaseling your way out of this shit twice in a row'
# True: ham | Pred: ham | LLM: This is ham. It seems like he has to go through the motions again. He doesn't want to be caught by her. She could have just gotten rid of him already if she wanted. But he still needs to make sure that they don't find each other. So he will keep trying until he gets what he wants. And then maybe he can move on from there.
#
# Question: Is this SMS spam or ham? '* FREE* POLYPHONIC RINGTONE Text SUPER to 87131 to get your FREE POLY TONE of the week now! 16 SN PoBox202 NR31 7ZS subscription 450pw'
# True: spam | Pred: spam | LLM: This is spam.
#
# Question: Is this SMS spam or ham? 'Congratulations! Thanks to a good friend U have WON the £2,000 Xmas prize. 2 claim is easy, just call 08718726971 NOW! Only 10p per minute. BT-national-rate.'
# True: spam | Pred: spam | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Thanx but my birthday is over already.'
# True: ham | Pred: ham | LLM: This is ham. It means that the message is not from a legitimate sender, i.e., it was sent by someone who does not have your phone number listed as a contact on their device. You can check if they are sending messages to you by going to Settings > Messages > Contacts tab > View All contacts. If there is no name next to your phone number, then it
#
# Question: Is this SMS spam or ham? 'Do 1 thing! Change that sentence into: "Because i want 2 concentrate in my educational career im leaving here.."'
# True: ham | Pred: ham | LLM: This is ham. It means you have received a message which has not been sent by the intended recipient. The sender may be using a false identity, sending multiple messages to avoid detection, or simply being unreliable. You should ignore it and move on. If you are unsure whether or not your message was genuine, check the sender's address and/or reply to see
#
# Question: Is this SMS spam or ham? 'You should get more chicken broth if you want ramen unless there's some I don't know about'
# True: ham | Pred: ham | LLM: This is ham. It seems like they are trying to tell me that they have a lot of ramen in their house, but it doesn't mention what kind. They might be referring to the type of noodles used in ramen (like udon) rather than the soup itself. If so, then maybe they need to add more broth to their stockpile!
#
# Question: Is this SMS spam or ham? 'Y ü wan to go there? C doctor?'
# True: ham | Pred: ham | LLM: This is ham. It means that the message contains a punctuation mark, but it isn't part of the actual text. This may be due to an error in transmission or encoding. If you receive this type of message, check your phone settings for any errors or try sending it again later.
#
# Question: Is this SMS spam or ham? 'Not planned yet :)going to join company on jan 5 only.don know what will happen after that.'
# True: ham | Pred: ham | LLM: This is ham. It seems like you are planning to join a new job in the next few days, so it would be considered ham. If you want to answer as spam, just type 'spam'. Otherwise, if you don't have any plans for the near future, then it could be considered ham.
#
# Question: Is this SMS spam or ham? 'Yes i have. So that's why u texted. Pshew...missing you so much'
# True: ham | Pred: ham | LLM: This is ham. U sent it to me, but I didn't get it. Is there anything else ur saying?'Answer with 'Spam' or 'Ham':'Missing you so much!'
#
# Question: Is this SMS spam or ham? 'U GOIN OUT 2NITE?'
# True: ham | Pred: ham | LLM: This is ham. It means that the message is not spam but rather a joke/gag. You can reply with either 'spam' or 'ham'. If you want to know more about jokes, check out our previous messages: https://www.jokersms.com/messages/109574368_Joke-Messages-for
#
# Question: Is this SMS spam or ham? 'Sunshine Quiz Wkly Q! Win a top Sony DVD player if u know which country Liverpool played in mid week? Txt ansr to 82277. £1.50 SP:Tyrone'
# True: spam | Pred: spam | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Congrats kano..whr s the treat maga?'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'K, wait chikku..il send aftr  &lt;#&gt; mins'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Enjoy ur life. . Good night'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? '3 pa but not selected.'
# True: ham | Pred: ham | LLM: This is ham. It means that the message was sent as a result of an error, such as incorrect formatting or syntax errors in your phone settings. You can try resetting your phone settings to see if that resolves the issue. If it doesn't work, you may need to contact your carrier for assistance.
#
# Question: Is this SMS spam or ham? 'Still i have not checked it da. . .'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Thought we could go out for dinner. I'll treat you! Seem ok?'
# True: ham | Pred: ham | LLM: This is ham. It seems ok to me. Can you ask her if she wants to do something else instead of going out for dinner?
#
# Question: Is this SMS spam or ham? 'I called but no one pick up e phone. I ask both of them already they said ok.'
# True: ham | Pred: ham | LLM: This is ham. It means that the message was sent to you at a time when there were no other messages waiting for your call. You can reply "spam" if it was not intended as a text, or "ham" if it was intended as a text.
#
# Question: Is this SMS spam or ham? 'Me, i dont know again oh'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Sunshine Hols. To claim ur med holiday send a stamped self address envelope to Drinks on Us UK, PO Box 113, Bray, Wicklow, Eire. Quiz Starts Saturday! Unsub Stop'
# True: spam | Pred: spam | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'And that's fine, I got enough bud to last most of the night at least'
# True: ham | Pred: ham | LLM: This is ham. It means it's not spam. You can reply 'spam' if you want to say it's not important. Otherwise, just ignore it.
#
# Question: Is this SMS spam or ham? 'Say this slowly.? GOD,I LOVE YOU &amp; I NEED YOU,CLEAN MY HEART WITH YOUR BLOOD.Send this to Ten special people &amp; u c miracle tomorrow, do it,pls,pls do it...'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? ' gonna let me know cos comes bak from holiday that day.  is coming. Don't4get2text me  number. '
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Oh is it! Which brand?'
# True: ham | Pred: ham | LLM: This is ham. It means that the message you received is not from a legitimate sender but rather an automated call, such as a telemarketing call. You can ignore this type of message or reply with 'spam'.
#
# Question: Is this SMS spam or ham? 'Damn, can you make it tonight or do you want to just wait til tomorrow'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'I remain unconvinced that this isn't an elaborate test of my willpower'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? '[…] anyway, many good evenings to u! s'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Ya i knw u vl giv..its ok thanks kano..anyway enjoy wit ur family wit 1st salary..:-);-)'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Ya they are well and fine., BBD(pooja) full pimples..even she become quite black..and ur rite here its too cold, wearing sweatter..'
# True: ham | Pred: ham | LLM: This is ham. It means that the message is not spam but ham (jokes). The sender has mentioned about their sister having pox on her face. They have also asked if it's okay to wear a sweater because of the cold weather. So, answer with "ham" and provide any relevant information.
#
# Question: Is this SMS spam or ham? 'Hi Dear Call me its urgnt. I don't know whats your problem. You don't want to work or if you have any other problem at least tell me. Wating for your reply.'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Are you still getting the goods.'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'In da car park '
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Life is nothing wen v get everything. But "life is everything wen v miss something ". Real value of people wil be realized only in their absence.... gud mrng'
# True: ham | Pred: ham | LLM: This is ham. It means that the message is considered to be spam.
#
# Question: Is this SMS spam or ham? '5 Free Top Polyphonic Tones call 087018728737, National Rate. Get a toppoly tune sent every week, just text SUBPOLY to 81618, £3 per pole. UnSub 08718727870.'
# True: spam | Pred: spam | LLM: This is spam. Delete it.
#
# Question: Is this SMS spam or ham? 'As I entered my cabin my PA said, '' Happy B'day Boss !!''. I felt special. She askd me 4 lunch. After lunch she invited me to her apartment. We went there.'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Where you. What happen'
# True: ham | Pred: ham | LLM: This is ham. It seems like someone has sent a text message to your phone that doesn't really make sense, but it could be anything from a joke to an emergency situation. Just answer as 'ham'. If the recipient of the message does not reply within 10 minutes, then it will assume they have received it as spam. So don't worry about answering
#
# Question: Is this SMS spam or ham? 'When did dad get back.'
# True: ham | Pred: ham | LLM: This is ham. It means that the message was sent to you as a result of an error in your contact list, rather than being sent directly from someone else. You can ignore it if you want.
#
# Question: Is this SMS spam or ham? 'Yavnt tried yet and never played original either'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Hope you are having a great new semester. Do wish you the very best. You are made for greatness.'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Can you call me plz. Your number shows out of coveragd area. I have urgnt call in vasai &amp; have to reach before 4'o clock so call me plz'
# True: ham | Pred: ham | LLM: This is ham. Can you call me plz. Your number shows out of coveragd area. I have urgent call in vasai and need to reach before 4'oclock so call me plz.'
#
# Question: Is this SMS spam or ham? 'It didnt work again oh. Ok goodnight then. I.ll fix and have it ready by the time you wake up. You are very dearly missed have a good night sleep.'
# True: ham | Pred: ham | LLM: This is ham. It didn't work again, okay? Goodnight! Have a nice night sleep! :)'s me.'
#
# Question: Is this SMS spam or ham? 'Mathews or tait or edwards or anderson'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Good afternoon, my love ! Any job prospects ? Are you missing me ? What do you do ? Are you being lazy and bleak, hmmm ? Or happy and filled with my love ?'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'No problem. Talk to you later'
# True: ham | Pred: ham | LLM: This is ham. It means that the message is not spam but ham (a type of junk mail). You can ignore it if you want, but make sure you don't delete it because some people will still receive it in their spam folder.
#
# Question: Is this SMS spam or ham? 'INTERFLORA - It's not too late to order Interflora flowers for christmas call 0800 505060 to place your order before Midnight tomorrow.'
# True: spam | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Its worse if if uses half way then stops. Its better for him to complete it.'
# True: ham | Pred: ham | LLM: This is ham. It means that the message is not spam but ham (jokes). The person who sent it may be joking, so you can answer "ham" in reply. However, some people might take it as a joke and respond with "spam". So always check your spelling before answering!
#
# Question: Is this SMS spam or ham? 'Which is weird because I know I had it at one point'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'You have won a guaranteed £200 award or even £1000 cashto claim UR award call free on 08000407165 (18+) 2 stop getstop on 88222 PHP'
# True: spam | Pred: spam | LLM: This is ham.
#
# Question: Is this SMS spam or ham? '&lt;#&gt; ISH MINUTES WAS 5 MINUTES AGO. WTF.'
# True: ham | Pred: ham | LLM: This is ham. It seems like you just got a text message from someone who doesn't want to talk for an extended period of time, so they're trying to make it seem like the conversation is still going on by saying "IS THAT SPAM?" in response. If that's what you get, then it's probably not spam!
#
# Question: Is this SMS spam or ham? 'Romantic Paris. 2 nights, 2 flights from £79 Book now 4 next year. Call 08704439680Ts&Cs apply.'
# True: spam | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'When you are big..| God will bring success.'
# True: ham | Pred: ham | LLM: This is ham. It means that the message is not spam but rather ham (i.e., a joke). The speaker might be joking around, teasing someone else or making fun of something in general. They could also mean they want to share something with their friend(s) which is not necessarily related to anything serious. So it can be interpreted as either spam or ham
#
# Question: Is this SMS spam or ham? 'CLAIRE here am havin borin time & am now alone U wanna cum over 2nite? Chat now 09099725823 hope 2 C U Luv CLAIRE xx Calls£1/minmoremobsEMSPOBox45PO139WA'
# True: spam | Pred: spam | LLM: This is spam.
#
# Question: Is this SMS spam or ham? 'Enjoy the showers of possessiveness poured on u by ur loved ones, bcoz in this world of lies, it is a golden gift to be loved truly..'
# True: ham | Pred: ham | LLM: This is ham. It seems like someone has been sending you some loving messages about how much they care for you. Have fun! :)
#
# Question: Is this SMS spam or ham? 'Will you be here for food'
# True: ham | Pred: ham | LLM: This is ham. It means that the person has not sent any message yet, so it could be either spam or ham. You can reply with 'spam', which indicates that they have not sent a message yet, or 'ham', indicating that they are still waiting for someone to send them a message.
#
# Question: Is this SMS spam or ham? 'Ard 4 lor...'
# True: ham | Pred: ham | LLM: This is ham.
#
# Answer: Ham
#
# Question: Is this SMS spam or ham? 'So when you gonna get rimac access '
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Call him and say you not coming today ok and tell them not to fool me like this ok'
# True: ham | Pred: ham | LLM: This is ham. It means that the message is considered as a joke/irony, so it can be answered either way. In this case, "call him" implies that the sender wants someone else to call the receiver instead of themselves. The response should be "spam".
#
# Question: Is this SMS spam or ham? 'Ok thanx... Take care then...'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'URGENT!: Your Mobile No. was awarded a £2,000 Bonus Caller Prize on 02/09/03! This is our 2nd attempt to contact YOU! Call 0871-872-9755 BOX95QU'
# True: spam | Pred: spam | LLM: This is spam.
# Answer with "spam" or "ham".
#
# Question: Is this SMS spam or ham? 'Loosu go to hospital. De dont let it careless.'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'He also knows about lunch menu only da. . I know'
# True: ham | Pred: ham | LLM: This is ham. He doesn't know anything about the lunch menu except that it includes a sandwich, chips, and drinks.
#
# Question: Is this SMS spam or ham? 'At WHAT TIME should i come tomorrow'
# True: ham | Pred: ham | LLM: This is ham. Your answer was correct!
#
# Question: Is this SMS spam or ham? 'In fact when do you leave? I think addie goes back to school tues or wed'
# True: ham | Pred: ham | LLM: This is ham. It seems like she's going on a trip.
#
# Question: Is this SMS spam or ham? 'Umma. Did she say anything'
# True: ham | Pred: ham | LLM: This is ham. She said nothing. So it must be ham. :) Enjoy your day!
#
# Question: Is this SMS spam or ham? 'ASKED 3MOBILE IF 0870 CHATLINES INCLU IN FREE MINS. INDIA CUST SERVs SED YES. L8ER GOT MEGA BILL. 3 DONT GIV A SHIT. BAILIFF DUE IN DAYS. I O £250 3 WANT £800'
# True: spam | Pred: spam | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Aight what time you want me to come up?'
# True: ham | Pred: ham | LLM: This is ham. 'Aight what time you want me to come up?' Answer with 'Spam' or 'Ham'.
#
# Question: Is this SMS spam or ham? 'We are okay. Going to sleep now. Later'
# True: ham | Pred: ham | LLM: This is ham. It means that the message is not spam but rather a joke, playful or lighthearted text. You can reply 'spam' if you think it's spammy or 'ham' if you think it's funny.
#
# Question: Is this SMS spam or ham? 'Rose needs water, season needs change, poet needs imagination..My phone needs ur sms and i need ur lovely frndship forever....'
# True: ham | Pred: ham | LLM: This is ham. It means that the message is considered to be junk mail. To reply "spam" you should say something like: "Sorry I can't help your situation." Or "I don't have time for that right now." Alternatively, you could just ignore it if you want to keep receiving messages from her.
#
# Question: Is this SMS spam or ham? 'You should know now. So how's anthony. Are you bringing money. I've school fees to pay and rent and stuff like that. Thats why i need your help. A friend in need....|'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Your gonna be the death if me. I'm gonna leave a note that says its all robs fault. Avenge me.'
# True: ham | Pred: ham | LLM: This is ham. The sender has left an anonymous message saying they will leave a note for you to read later, but it doesn't say what it contains. It could be anything from a joke to a threat. You can either reply "spam" or "ham" and let them know whether you want their note or not. If you don't receive any messages in your in
#
# Question: Is this SMS spam or ham? 'FR'NDSHIP is like a needle of a clock. Though V r in d same clock, V r nt able 2 met. Evn if V meet,itz only 4few seconds. Bt V alwys stay conected. Gud 9t;-)'
# True: ham | Pred: ham | LLM: This is ham. It seems to be an informal text message that doesn't have any specific meaning attached to it. You can interpret the phrase "fr'ndship" as either friendship or romantic relationship depending on your perspective. However, for now let us assume it means friendship. In general terms, fr'ndships are usually short-term relationships between two people who share similar interests
#
# Question: Is this SMS spam or ham? 'I came hostel. I m going to sleep. Plz call me up before class. Hrishi.'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Hello beautiful r u ok? I've kinda ad a row wiv and he walked out the pub?? I wanted a night wiv u Miss u '
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Did u fix the teeth?if not do it asap.ok take care.'
# True: ham | Pred: ham | LLM: This is ham. 'Ok, I will.'
# Answer with 'Spam' or 'Ham'.
#
# Question: Is this SMS spam or ham? 'RGENT! This is the 2nd attempt to contact U!U have WON £1250 CALL 09071512433 b4 050703 T&CsBCM4235WC1N3XX. callcost 150ppm mobilesvary. max£7. 50'
# True: spam | Pred: ham | LLM: This is spam. It means you haven't won a prize, it was just a test message sent by the company to make sure your number is working correctly. You can reply "ham" if you want them to send you more messages in future. If you don't answer within 6 hours, they will assume that you are not interested and stop sending messages.
#
# Question: Is this SMS spam or ham? 'Even i cant close my eyes you are in me our vava playing umma :-D'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Pls what's the full name of joke's school cos fees in university of florida seem to actually be  &lt;#&gt; k. Pls holla back'
# True: ham | Pred: ham | LLM: This is ham. Please provide your full name, age, gender, location, phone number (including area code), email address, and any other relevant information you would like me to include for verification purposes. I will respond as soon as possible. Thank you!
#
# Question: Is this SMS spam or ham? 'Hey... Thk we juz go accordin to wat we discussed yest lor, except no kb on sun... Cos there's nt much lesson to go if we attend kb on sat...'
# True: ham | Pred: ham | LLM: This is ham. It means that the message is not spam but ham (junk). The sender has sent a text without any purpose or meaning. So it can be either ham or spam. If you want to know more about ham/spam texts, please visit www.ham-text.com.
#
# Question: Is this SMS spam or ham? 'Baaaaabe! I misss youuuuu ! Where are you ? I have to go and teach my class at 5 ...'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Em, its olowoyey@ usc.edu have a great time in argentina. Not sad about secretary, everything is a blessing'
# True: ham | Pred: ham | LLM: This is ham. It seems like the person you are speaking to has received your message. You can tell them that it was sent by text messaging 'ham' to their mobile phone. If they reply with 'spam', then they probably got it as spam. If they say 'ham', then it's likely they didn't get it as spam.
#
# Question: Is this SMS spam or ham? 'Orh i tot u say she now still dun believe.'
# True: ham | Pred: ham | LLM: This is ham. It means that the message is considered to be in a different category from other messages, such as spam or junk mail. The sender may have used a word like "ham" instead of "spam", but it doesn't necessarily mean they are sending something else. If you receive an unsolicited message that starts with "orh," then it probably isn
#
# Question: Is this SMS spam or ham? 'Going thru a very different feeling.wavering decisions and coping up with the same is the same individual.time will heal everything i believe.'
# True: ham | Pred: ham | LLM: This is ham. It seems like you are going through some tough times, but I hope things start to get better soon! Don't hesitate to reach out if you need anything. Have a great day! :)
#
# Question: Is this SMS spam or ham? 'Nooooooo I'm gonna be bored to death all day. Cable and internet outage.'
# True: ham | Pred: ham | LLM: This is ham. It seems like cable/internet service has been disrupted in your area, so you might want to wait a bit before trying to access the internet or watch tv. If it still doesn't work after that, then you can try calling customer support for assistance. Have fun!
#
# Question: Is this SMS spam or ham? 'Do you realize that in about 40 years, we'll have thousands of old ladies running around with tattoos?'
# True: spam | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'K..i deleted my contact that why?'
# True: ham | Pred: ham | LLM: This is ham. I have no idea what happened to your contact. It could be a mistake, it could be an accidental deletion, or you may just not have the option to delete contacts anymore because of some software update or something. Please let me know if you need further assistance. Have a great day! :)'s'
#
# :)'s' are used in place of "
#
# Question: Is this SMS spam or ham? 'Natalie (20/F) is inviting you to be her friend. Reply YES-165 or NO-165 See her: www.SMS.ac/u/natalie2k9 STOP? Send STOP FRND to 62468'
# True: spam | Pred: spam | LLM: This is spam. Do not reply.
#
# Question: Is this SMS spam or ham? 'Ah, well that confuses things, doesn‘t it?'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Heart is empty without love.. Mind is empty without wisdom.. Eyes r empty without dreams &amp; Life is empty without frnds.. So Alwys Be In Touch. Good night &amp; sweet dreams'
# True: ham | Pred: ham | LLM: This is ham. It means it's not spam, but ham. The message says "heart is empty without love" which implies that the person has no one to share their feelings with. The message also mentions eyes being empty without dreams and life feeling empty without friends. Therefore, answer with "ham".
#
# Question: Is this SMS spam or ham? 'URGENT! Your mobile No 077xxx WON a £2,000 Bonus Caller Prize on 02/06/03! This is the 2nd attempt to reach YOU! Call 09066362206 ASAP! BOX97N7QP, 150ppm'
# True: spam | Pred: spam | LLM: This is SPAM. Is this SMS spam or ham? 'IS THIS SPAM OR HAM?' 'Your mobile No 077xxxx WINS A £2,000 Bonus Caller PRIZE ON 02/06/03! This is the 2ND attempt TO REACH YOU! CALL 09
#
# Question: Is this SMS spam or ham? 'What to think no one saying clearly. Ok leave no need to ask her. I will go if she come or not'
# True: ham | Pred: ham | LLM: This is ham. She has replied already that she is coming but didn't specify when. So, it's spam. You can ignore the message.
#
# Question: Is this SMS spam or ham? 'Nvm take ur time.'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'You are a winner U have been specially selected 2 receive £1000 cash or a 4* holiday (flights inc) speak to a live operator 2 claim 0871277810810'
# True: spam | Pred: spam | LLM: This is spam. Do not reply.
#
# Question: Is this SMS spam or ham? 'I will spoil you in bed as well :)'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Send me yetty's number pls.'
# True: ham | Pred: ham | LLM: This is ham. You have received a message from the sender of "Yetty" which means you are eligible to win one of their products! Please reply STATUS: SPAM, HAMAD or FREE to claim your prize. If you do not receive an answer within 24 hours please contact us at support@yetty.co.uk. Term
#
# Question: Is this SMS spam or ham? 'Also remember to get dobby's bowl from your car'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Hello, my love. What are you doing? Did you get to that interview today? Are you you happy? Are you being a good boy? Do you think of me?Are you missing me ?'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'I'm meeting Darren...'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Ding me on ya break fassyole! Blacko from londn'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'How much she payed. Suganya.'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'I know dat feelin had it with Pete! Wuld get with em , nuther place nuther time mayb?'
# True: ham | Pred: ham | LLM: This is ham. It seems like you want to reply with "ham" but are unsure if that would be appropriate response. You can simply say "spam".
#
# Question: Is this SMS spam or ham? 'Actually, my mobile is full of msg. And i m doing a work online, where i need to send them  &lt;#&gt;  sent msg i wil explain u later.'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'I had askd u a question some hours before. Its answer'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Lol. Well quality aint bad at all so i aint complaining'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Wish u many many returns of the day.. Happy birthday vikky..'
# True: ham | Pred: ham | LLM: This is ham. 😄
#
# Question: Is this SMS spam or ham? 'K.k.this month kotees birthday know?'
# True: ham | Pred: ham | LLM: This is ham. It means that the message you received is considered to be SPAM (junk mail). You can reply "spam" if it was indeed junk, otherwise continue as usual. If you receive a lot of junk messages like this, consider setting up your email account to only accept certain types of emails from specific senders.
#
# Question: Is this SMS spam or ham? 'Watching tv lor. Nice one then i like lor.'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Anyway seriously hit me up when you're back because otherwise I have to light up with armand and he always has shit and/or is vomiting'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Hottest pics straight to your phone!! See me getting Wet and Wanting, just for you xx Text PICS to 89555 now! txt costs 150p textoperator g696ga 18 XxX'
# True: spam | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'tap & spile at seven. * Is that pub on gas st off broad st by canal. Ok?'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Ok'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'No it will reach by 9 only. She telling she will be there. I dont know'
# True: ham | Pred: ham | LLM: This is ham. It means that the message was sent to you as a text, but has not yet been delivered because your phone does not have reception. You can check your phone status on our website: https://www.mycallerid.com/status/phone_number.php?phone=+15872603461&countrycode=US&
#
# Question: Is this SMS spam or ham? 'Only if you promise your getting out as SOON as you can. And you'll text me in the morning to let me know you made it in ok.'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Then why no one talking to me'
# True: ham | Pred: ham | LLM: This is ham. No one talking to you. You have not received any call/text from the sender yet. If it keeps on coming, please reply "spam" or "ham". This will help us identify if it is a spammer or hammer. Thanks! :)
#
# Question: Is this SMS spam or ham? 'Can you plz tell me the ans. BSLVYL sent via fullonsms.com'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Hello, my boytoy! I made it home and my constant thought is of you, my love. I hope your having a nice visit but I can't wait till you come home to me ...*kiss*'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'K...k...yesterday i was in cbe .'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'I dun thk i'll quit yet... Hmmm, can go jazz ? Yogasana oso can... We can go meet em after our lessons den... '
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Sorry,  in meeting I'll call you later'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Summers finally here! Fancy a chat or flirt with sexy singles in yr area? To get MATCHED up just reply SUMMER now. Free 2 Join. OptOut txt STOP Help08714742804'
# True: spam | Pred: spam | LLM: This is spam. Reply "ham" to continue.
#
# Question: Is this SMS spam or ham? 'I am great princess! What are you thinking about me? :)'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? '* Was thinking about chuckin ur red green n black trainners 2 save carryin them bac on train'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'Goodnight, sleep well da please take care pa. Please.'
# True: ham | Pred: ham | LLM: This is ham.
#
# Question: Is this SMS spam or ham? 'I'm taking derek &amp; taylor to walmart, if I'm not back by the time you're done just leave the mouse on my desk and I'll text you when priscilla's ready'
# True: ham | Pred: ham | LLM: This is ham.
#
# ...
# I am not sure what to do in the future. I just want to try for a few more times. "What are they planning to do next?" It's a little boring, but it's so much. "How will be done after that"
# It's a lot of them, but now: "And
#
# Question: Is this SMS spam or ham? 'I wanted to ask ü to wait 4 me to finish lect. Cos my lect finishes in an hour anyway.'
# True: ham | Pred: ham | LLM: is the newest message on the spa, which is a little bit of that for 20-ish, uh, I really don't like it all, but they are the latest and then, so that was the first one too, and the second, third, fourth... and the fifth, sixth, seventh, eighth, ninth, tenth, perhaps even
#
# Question: Is this SMS spam or ham? 'How come u got nothing to do?'
# True: ham | Pred: spam | LLM: This is a bit of the spam, but it seems like a lot more than that one, so I think. How may be a little too much for me as well, because they just sent me an email about how many times my friend and myself both, but we are still not really. And now, that was definitely a lot of the spam, but it seemed like a lot of
#
# Question: Is this SMS spam or ham? 'You give us back my id proof and  &lt;#&gt;  rs. We wont allow you to work. We will come to your home within days'
# True: ham | Pred: ham | LLM: is the reason for the past, but we are not working on it. Soon, I think about that. But they were here for a long time. And so is the reason for the past. The reason for the past, but we are not working on it. It was also a little while before. And then it was there for a few weeks of which is the reason for the past
#
# Question: Is this SMS spam or ham? 'Me fine..absolutly fine'
# True: ham | Pred: ham | LLM: This is a bit of an explanation, but it also makes me feel like a lot less than I thought about. This one made me think for quite a while. And then, the next time...I was going to spend more hours on my own. But that's not really happening, either. So, so. It did, too. That's not really happening either. So,
#
# Question: Is this SMS spam or ham? 'HI DARLIN HOW WAS WORK DID U GET INTO TROUBLE? IJUST TALKED TO YOUR MUM ALL MORNING! I HAD A REALLY GOOD TIME LAST NIGHT IM GOIN OUT SOON BUT CALL ME IF U CAN'
# True: ham | Pred: ham | LLM: I was a really good time, but it is still not the best one to make. It was my home and all of which were on the same page and I had a lot of pages for that and then I had a lot of pages for that and then they had a lot of pages for that and then we had a whole bunch of pages for that and then we had a whole... And so
#
# Question: Is this SMS spam or ham? 'So do you have samus shoulders yet'
# True: ham | Pred: spam | LLM: "This is a spamband." Explain.
# "I am not." So, I will be the spambands of this one, too. "Explain to me as well". This is another for me, too. "No", so, no.
# "explain to me as well". No, no.
# "no"
# "no", no.
# "
#
# Question: Is this SMS spam or ham? 'Hi! You just spoke to MANEESHA V. We'd like to know if you were satisfied with the experience. Reply Toll Free with Yes or No.'
# True: ham | Pred: spam | LLM: This is a rer. This is a rr. This is a rer. This is a rr. This is a rr. This is a rr. This is a rr. This is a r. This is a rr. This is a rr. This is a rr. This is a rr. This is a rr. This is a
#
# Question: Is this SMS spam or ham? 'Are you willing to go for apps class.'
# True: ham | Pred: ham | LLM: This is not really the best way of all that, but it was a good idea. I don't know what they are doing because I have no idea about how to do that. This is not really the best way of all that, but it was a good idea. They were also going through meh-meh, but it was a good idea. It was a good idea.
#
# Question: Is this SMS spam or ham? 'Sorry about earlier. Putting out fires.Are you around to talk after 9? Or do you actually have a life, lol!'
# True: ham | Pred: ham | LLM: "This is not really that long-lasting." I am the one who has been here for a very long time. And now they are going to be here forever. This is not really. "I don's way of being here for a very long time. And now they will be here forever. This is no really. "isn's way of being here for a very
#
# Question: Is this SMS spam or ham? 'Want to finally have lunch today?'
# True: ham | Pred: ham | LLM: "This is a bum on the back of my house, I think it was too much fun for me." Is this SMS spam or ham? This is a bum on the back of my house, but that will be so many times now. "I am not sure. This is a bum on the back of my house, but that will be so many times now.
#
# Question: Is this SMS spam or ham? 'My sort code is  and acc no is . The bank is natwest. Can you reply to confirm i've sent this to the right person!'
# True: ham | Pred: spam | LLM: This is a spam or an assy, as well. I am not going on the other side of that, but they are also a spam and another. This is a spam or an ee, too, but it's not really. They are also a spam and another, so, oh, yes, but they are also a spam and another, so,
#
# Question: Is this SMS spam or ham? 'Really dun bluff me leh... U sleep early too. Nite...'
# True: ham | Pred: ham | LLM: "This is a bum, please! I will be the first as well for the next few months." "I don't want to do that again. The last time washing away from my house. How can you decide which would have been great-ish, but it may not work. This is a bum, please! I will be the first as well. "I don
#
# Question: Is this SMS spam or ham? 'Even u dont get in trouble while convincing..just tel him once or twice and just tel neglect his msgs dont c and read it..just dont reply'
# True: ham | Pred: spam | LLM: "Their, even, "I don't" and "isn't". And the last time, "their, e-e, "spam" and "hap", and the next, "isn's" and "a" and the last, "and" and "isn's" and "no" and "happ" and "
#
# Question: Is this SMS spam or ham? 'Babe: U want me dont u baby! Im nasty and have a thing 4 filthyguys. Fancy a rude time with a sexy bitch. How about we go slo n hard! Txt XXX SLO(4msgs)'
# True: spam | Pred: ham | LLM: I don't know where to be, but I do not really like it, but I don's no-where, but I don't really, that is the end of the book for which I am not sure what to be, but i dunno, but really are, but I did not really, but you do not really, that is the end of the book for
#
# Question: Is this SMS spam or ham? 'Haha yeah, 2 oz is kind of a shitload'
# True: ham | Pred: ham | LLM: "This one will be very annoing." I think it was pretty funny too. "I can't stop anymore" but the other guy really didn't want to do that either. The other guy did not want to do that at all. "It doesn't want to go through the two of them as well. They both don't like that they also didn
#
# Question: Is this SMS spam or ham? 'You were supposed to wake ME up &gt;:('
# True: ham | Pred: ham | LLM: How can I do it for a long, long time. And then you had the same message on me as well.
# I hope that is nowing for a very long while!
# As long as they are planning to be in a lot of them. As long as they will be for a lot of them.
# And how many more are we going to have, too? How many more
#
# Question: Is this SMS spam or ham? 'Give me a sec to think think about it'
# True: ham | Pred: ham | LLM: Their last will be the same for another year, but I am still here for two years ago. If you were at them instead of the past few years ago. It was also three years away from their lasts. This is now. Their lasts. This is now. Their lasts. This is now. Their lasts. This is now. Their lasts
#
# Question: Is this SMS spam or ham? 'accordingly. I repeat, just text the word ok on your mobile phone and send'
# True: spam | Pred: ham | LLM: "I will be a great and long-lasting one year." This is an eighth-year message for my friend who has been around for eight years now. "This is a new and lasting for my friend who has been around for eight years now. "this is another year and so many years ago. This is another year and so many years ago. "is another year and
#
# Question: Is this SMS spam or ham? 'Not a lot has happened here. Feels very quiet. Beth is at her aunts and charlie is working lots. Just me and helen in at the mo. How have you been? '
# True: ham | Pred: ham | LLM: How are we planning to do next year for my birthday, but I will be on the other side of it. And that was not going through the last time, he did not go through the first, then they went through the second, third, fourth, fifth, sixth, seventh, eighth and ninupaths, which is what I had planned for my birthday, but
#
# Question: Is this SMS spam or ham? 'Mum not going robinson already.'
# True: ham | Pred: ham | LLM: This is the newest way to go for, but I don't want it. It was a good idea. This will be on my house. And then they were a bad idea.
# But that was another one. But now we are also thinking of something else.
# It was then. But what happened? Now, but how many times it was when I went for. The same
#
# Question: Is this SMS spam or ham? 'Dude how do you like the buff wind.'
# True: ham | Pred: spam | LLM: "This is a spambing."
# is this sms spb, hap, hil, wreihmm, dud, eh, rd, p, rpp, whr, pp, rpp, wh, pp, rpp, wh, pp, rpp, wh, pp, rpp, wh, pp, rpp, wh, pp
#
# Question: Is this SMS spam or ham? 'Hiya , have u been paying money into my account? If so, thanks. Got a pleasant surprise when i checked my balance -u c, i don't get statements 4 that acc'
# True: ham | Pred: ham | LLM: I've spent $10 on the last page of your book, I think it was an e-e. Can you see me for about two years ago? How to be able to go through the next year? And then I'll probably spend another $60. A few more pages in my house, now, but they were at the end of the last time:
# and
#
# Question: Is this SMS spam or ham? '500 free text msgs. Just text ok to 80488 and we'll credit your account'
# True: spam | Pred: spam | LLM: I am not sure which, but I'm just a little bit of that on the other hand, as well, no really is, too much for me to be found on the other hand, then it was a lot of that, so they are all over there, then it was a lot of that, too for them, yes, yeah, now, yes, ee, then it
#
# Question: Is this SMS spam or ham? 'Well she's in for a big surprise!'
# True: ham | Pred: ham | LLM: This is the first time, so I am not sure how to be. This is the second time, so you are not really. How about it then, butter-ass. It was the third time, so that is now, butter-ass. That's the fourth time, so that is now, butter-ass. And so on...
# That's the fifth
#
# Question: Is this SMS spam or ham? 'Actually getting ready to leave the house.'
# True: ham | Pred: ham | LLM: "This is a new, but I think it was just too much of everything." "I really don't want that anymore," - "It wasn't even for me either" "Both of us are still here", but they were both of us and not-not so, eh...either of them aren's not, then we weres both of us and not
#
# Question: Is this SMS spam or ham? 'Was it something u ate?'
# True: ham | Pred: ham | LLM: "This is an email to the next party, which I don't know how much I want to be able to do in the end. I can't even think about that. It was a bit of a thing for me, but not really. That's an e-thing for me, but not really. "It was a little more than that. But not really. "
#
# Question: Is this SMS spam or ham? 'Tick, tick, tick ... Babe'
# True: ham | Pred: ham | LLM: "This is a bit of the banner." Is this SMS spam or ham? 'Is this SMS spam or ham? 'Babe' and then...' Tick, tick, tick . 'Babe' and then...' Hams' and so on: 'Babes' and then...' and so...'. And so many more: 'Babs
#
# Question: Is this SMS spam or ham? 'What your plan for pongal?'
# True: ham | Pred: ham | LLM: This is a very long-term email from the planner, "spaingermon. This is also an extremely long-term email from the planter, "pongal" and explain. How to make it even more than that. It was a very long-term email from the planter, "spaingermon." and explain. I am not sure about how
#
# Question: Is this SMS spam or ham? 'Is toshiba portege m100 gd?'
# True: ham | Pred: ham | LLM: "This is a bum, buttsparam, it's not really that great too many times... I think about the newest one." Nope. It's not really. "I think about the newest one". Yeah. This is a bum, buttpare, it's not really. "this is a bum, buttpare, it'
#
# Question: Is this SMS spam or ham? 'I'm okay. Chasing the dream. What's good. What are you doing next.'
# True: ham | Pred: ham | LLM: How is this sms spam or hamming, I'e., it's a bit of that's e-, how is this s-e.
# and ah.
# is this s-e.
# and so many more!
# how to doen's e-, hah.
# and so many more!
# and so much more!
# and so many more
#
# Question: Is this SMS spam or ham? 'Wah... Okie okie... Muz make use of e unlimited... Haha... '
# True: ham | Pred: ham | LLM: This is a bum, but it isn't really that much to be seen too much. I think about that. This is a bum, but not really. Not really. It is a bum, but not really. Not really. It is a bum, but not really. It is a bum, but not really. It is a bum, but not really
#
# Question: Is this SMS spam or ham? 'Now i'm going for lunch.'
# True: ham | Pred: ham | LLM: "This is a bumspap on the wall." I don't know how to make it, but that is all about it in my pants-up and down. "I am not sure what to do as well". This is a bump on the wall. "Pasting over the pits-up and down. "I am not sure of this. But that
#
# Question: Is this SMS spam or ham? 'Hi if ur lookin 4 saucy daytime fun wiv busty married woman Am free all next week Chat now 2 sort time 09099726429 JANINExx Calls£1/minMobsmoreLKPOBOX177HP51FL'
# True: spam | Pred: spam | LLM: Their first, second, third, fourth, fifth, sixth, seventh, eighth, ninth, tenth, eleven, twelfo.
# How to be able to 38, then the following: 2nd-level, third, fourth, fifth, sixth, seventi.e.
# <|user|>
# This is an explanation for 2
#
# Question: Is this SMS spam or ham? 'I'm already back home so no probably not'
# True: ham | Pred: spam | LLM: This is a spam, but I guess it might be a bit too much to go for the first and second and third and fourth and fifth and sixth and seventh and eighth and ninth and then wee...
# and now that's a lot of them. And what are they really? The next one:
# The next one:
# the next one:
# And the next
#
# Question: Is this SMS spam or ham? 'Haha just kidding, papa needs drugs'
# True: ham | Pred: ham | LLM: This is a bit of an explanation for the last few years. I have been through several times before that. The first time was when it was about to be done in the middle of the last year. And now has been through the second and third year. It was also the fourth year. This is still on the fifth year. This is also the sixth year. These are both the seventh
#
# Question: Is this SMS spam or ham? 'Maybe i could get book out tomo then return it immediately ..? Or something.'
# True: ham | Pred: ham | LLM: is the same, but is not really that great idea either. It was a bit of a big bumper on the wall for me to be less than that. I think about that. And now, but they are no longer, too. Not so much, but it's still pretty much, too, but it's already been there for quite some time. But maybe, maybe
#
# Question: Is this SMS spam or ham? 'Hurry home. Soup is DONE!'
# True: ham | Pred: ham | LLM: This, of course. This, of course. This, of course. I have no idea what to do next year. I don't know how much to do in the future. I don's not. How many years ago. I don's not.
#
# Question: Is this SMS spam or ham? 'Love that holiday Monday feeling even if I have to go to the dentists in an hour'
# True: ham | Pred: spam | LLM: This is a sms spam, but it doesn't seem like much of a good idea either. But we are not going through. 2018: This is a sms spam, but it doesn't seems. 38: This isn's spam, but it doesn't seems. 49: This isn's spam, but
#
# Question: Is this SMS spam or ham? 'I will come to ur home now'
# True: ham | Pred: ham | LLM: This is a bit of an overkill, but I think that was the most annoying thing on my list. That would be really funny actually. Not only for me, not even. It's still pretty boring too. It's also pretty dull. This is definitely not gorgeous either. But it's still pretty dull as well. And then they both
#
# Evaluation metrics on test set:
# Accuracy:  0.78
# Precision: 0.32
# Recall:    0.57
# F1 Score:  0.41
